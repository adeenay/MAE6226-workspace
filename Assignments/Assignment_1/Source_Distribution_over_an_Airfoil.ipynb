# %%
import math as mt
import numpy as np
from matplotlib import pyplot as py
# %matplotlib inline

# %%
# function for creating flow grid
def flowgrid (xstart, xend, ystart, yend, N):
    x = np.linspace(xstart,xend,N)
    y = np.linspace(ystart,yend,N)
    X,Y = np.meshgrid(x,y)
    return X,Y

# %%
# mesh definition
xstart, xend, ystart, yend, N = -1.0,2.0,-0.5,0.5,51
X,Y = flowgrid(xstart, xend, ystart, yend, N)

# %%
# Source Velocity and stream function definition
## functions for velocity and stream function with source or sink
def get_vel(strength, xs, ys, X, Y):
    u = strength/(2*np.pi)*(X-xs)/((X-xs)**2+(Y-ys)**2)
    v = strength/(2*np.pi)*(Y-ys)/((X-xs)**2+(Y-ys)**2)
    return u,v

def get_streamfun(strength, xs, ys, X, Y):
    psi = strength/(2*np.pi)*np.arctan2((Y-ys),(X-xs))
    return psi

# %%
# Parameters for sources
sigma_naca = np.loadtxt ('NACA0012_sigma.txt')
x_naca = np.loadtxt ('NACA0012_x.txt')
y_naca = np.loadtxt ('NACA0012_y.txt')

# Getting velocities and stream functions in a 3D array
U1 = np.ndarray([N, N, np.size(x_naca)],dtype = float)           #creating a 3D array for U,V and psi
V1 = np.ndarray([N, N, np.size(x_naca)],dtype = float)
psi1 = np.ndarray([N, N, np.size(x_naca)],dtype = float)
for i in range (0,np.size(x_naca)-1):
    U1[:,:,i],V1[:,:,i] = get_vel (sigma_naca[i],x_naca[i],y_naca[i],X,Y)
    psi1[:,:,i] = get_streamfun (sigma_naca[i],x_naca[i],y_naca[i],X,Y)

# %%
# Free stream
u_inf = 1.0
psi_free = u_inf*Y

# %%
# Superposing free stream with set of sources
U = u_inf + np.sum(U1, axis=2)
V = np.sum(V1, axis=2)
psi = psi_free + np.sum(psi1, axis=2)

# %%
#plot
size = 20
py.figure(figsize = (size, (yend-ystart)/(xend - xstart)*size))
py.xlabel('x',fontsize = 16)
py.ylabel('y',fontsize = 16)
py.xlim(xstart,xend)
py.ylim(ystart,yend)
py.streamplot(X,Y,U,V, density = 2, linewidth=1, arrowsize=1, arrowstyle='->')
py.scatter(x_naca ,y_naca, color = '#CD2305', s=30, marker = 'o')

# %%
# Pressure Field
cp = 1.0 - (U**2+V**2)/u_inf

cp_max = np.max(cp)
x_maxcp, y_maxcp = np.where (cp == np.max(cp))

# Plotting pressure field
size = 15
py.figure(figsize = (size, (yend-ystart)/(xend - xstart)*size))
py.xlabel('x',fontsize = 16)
py.ylabel('y',fontsize = 16)
py.xlim(xstart,xend)
py.ylim(ystart, yend)
contf = py.contourf(X, Y, cp, extend = 'both') 
cbar = py.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
py.scatter(x_naca, y_naca, color = '#CD2305', s=30, marker = 'o')
py.scatter(X[x_maxcp,y_maxcp],Y[x_maxcp,y_maxcp], color = 'white', s=80, marker='*')

# %% [markdown]
#                     Point of Maximum Pressure Coefficient marked as a White Star in the above plot

# %%
# Scaling plot to visualize stagnation point
py.figure(figsize = (size, (yend-ystart)/(xend - xstart)*size))
py.xlabel('x',fontsize = 16)
py.ylabel('y',fontsize = 16)
py.xlim(-0.1,0.2)
py.ylim(-0.2, 0.2)
contf = py.contourf(X, Y, cp, extend = 'both', cmap = 'jet') 
cbar = py.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
py.scatter(x_naca, y_naca, color = '#CD2305', s=30, marker = 'o')
py.scatter(X[x_maxcp,y_maxcp],Y[x_maxcp,y_maxcp], color = 'white', s=80, marker='*')

# %%
X[x_maxcp,y_maxcp],Y[x_maxcp,y_maxcp]
# Out:
# (array([-0.04]), array([ 0.]))

# %% [markdown]
# # Questions
#
# 1. Where is the point of max pressure?
#
# Ans: At [-0.04,0]
#
# 2. What do we call that point?
#
# Ans: Stagnation Point
#
# 3. Will the airfoil generate any lift?
#
# Ans: No

# %% [markdown]
# # Think Section
#
# 1. Do the streamlines look like you expected?
#
# Ans: Yes. The streamlines curving around the airfoil are exactly as expected when modelling under potential flow assumptions
#
# 2. What does the pressure distribution tell you about lift generated by the airfoil?
#
# Ans: No lift will be generated as the pressure distrivbution is symmetric
#
# 3. Does the location of maximum pressure seem right?
#
# Ans: Yes. Since our modelling of the airfoil is point sources at all the co-ordinates, the stagnation point is a small distance away from the leading edge of the airfoil. This makes this approximation inaccurate. However, the solution can be more accurate if the grid is refined further, reducing the error.
